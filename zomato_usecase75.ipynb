# %%
pwd
# Out:
# 'C:\\Users\\Admin'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
zomato1=pd.read_csv("zomato.csv")

# %%
type(zomato1)
# Out:
# pandas.core.frame.DataFrame

# %%
zomato1.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
zomato1.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
zomato1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
zomato1.describe()
# Out:
#               votes
# count  51717.000000
# mean     283.697527
# std      803.838853
# min        0.000000
# 25%        7.000000
# 50%       41.000000
# 75%      198.000000
# max    16832.000000

# %%
zomato1.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
zomato2=zomato1.drop(['url','dish_liked','phone'],axis=1)

# %%
zomato2.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'cuisines', 'approx_cost(for two people)',
#        'reviews_list', 'menu_item', 'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
zomato2.head()
# Out:
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes      location            rest_type  \
# 0          Yes        Yes  4.1/5    775  Banashankari        Casual Dining
# 1          Yes         No  4.1/5    787  Banashankari        Casual Dining
# 2          Yes         No  3.8/5    918  Banashankari  Cafe, Casual Dining
# 3           No         No  3.7/5     88  Banashankari          Quick Bites
# 4           No         No  3.8/5    166  Basavanagudi        Casual Dining
#
# ...

# %%
zomato2.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51712    False
# 51713    False
# 51714    False
# 51715    False
# 51716    False
# Length: 51717, dtype: bool

# %%
zomato2.duplicated().sum()
# Out:
# 43

# %%
zomato2.shape
# Out:
# (51717, 14)

# %%
51717-43
# Out:
# 51674

# %%
zomato2.drop_duplicates(inplace=True)

# %%
zomato2.shape
# Out:
# (51674, 14)

# %%
zomato2.isnull()
# Out:
#        address   name  online_order  book_table   rate  votes  location  \
# 0        False  False         False       False  False  False     False
# 1        False  False         False       False  False  False     False
# 2        False  False         False       False  False  False     False
# 3        False  False         False       False  False  False     False
# 4        False  False         False       False  False  False     False
# ...        ...    ...           ...         ...    ...    ...       ...
# 51712    False  False         False       False  False  False     False
# 51713    False  False         False       False   True  False     False
# 51714    False  False         False       False   True  False     False
# 51715    False  False         False       False  False  False     False
# 51716    False  False         False       False  False  False     False
#
#        rest_type  cuisines  approx_cost(for two people)  reviews_list  \
# ...

# %%
zomato2.isnull().sum()
# Out:
# address                           0
# name                              0
# online_order                      0
# book_table                        0
# rate                           7767
# votes                             0
# location                         21
# rest_type                       227
# cuisines                         45
# approx_cost(for two people)     345
# reviews_list                      0
# menu_item                         0
# listed_in(type)                   0
# listed_in(city)                   0
# dtype: int64

# %%
7767+21+227+45+345
# Out:
# 8405

# %%
51674-8405
# Out:
# 43269

# %%
zomato2.shape
# Out:
# (51674, 14)

# %%
zomato2.dropna(how="any",inplace=True)

# %%
zomato2.shape
# Out:
# (43499, 14)

# %%
zomato2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43499 entries, 0 to 51716
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   address                      43499 non-null  object
#  1   name                         43499 non-null  object
#  2   online_order                 43499 non-null  object
#  3   book_table                   43499 non-null  object
#  4   rate                         43499 non-null  object
#  5   votes                        43499 non-null  int64
#  6   location                     43499 non-null  object
#  7   rest_type                    43499 non-null  object
#  8   cuisines                     43499 non-null  object
#  9   approx_cost(for two people)  43499 non-null  object
#  10  reviews_list                 43499 non-null  object
#  11  menu_item                    43499 non-null  object
#  12  listed_in(type)              43499 non-null  object
# ...

# %%
zomato2.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'cuisines', 'approx_cost(for two people)',
#        'reviews_list', 'menu_item', 'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
zomato3=zomato2.rename(columns={'approx_cost(for two people)':'cost',
                                'listed_in(type)':'type',
                               'listed_in(city)':'city'})

# %%
zomato3.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'cuisines', 'cost', 'reviews_list',
#        'menu_item', 'type', 'city'],
#       dtype='object')

# %%
zomato3.head()
# Out:
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes      location            rest_type  \
# 0          Yes        Yes  4.1/5    775  Banashankari        Casual Dining
# 1          Yes         No  4.1/5    787  Banashankari        Casual Dining
# 2          Yes         No  3.8/5    918  Banashankari  Cafe, Casual Dining
# 3           No         No  3.7/5     88  Banashankari          Quick Bites
# 4           No         No  3.8/5    166  Basavanagudi        Casual Dining
#
#                          cuisines cost  \
# ...

# %%
zomato3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43499 entries, 0 to 51716
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   address       43499 non-null  object
#  1   name          43499 non-null  object
#  2   online_order  43499 non-null  object
#  3   book_table    43499 non-null  object
#  4   rate          43499 non-null  object
#  5   votes         43499 non-null  int64
#  6   location      43499 non-null  object
#  7   rest_type     43499 non-null  object
#  8   cuisines      43499 non-null  object
#  9   cost          43499 non-null  object
#  10  reviews_list  43499 non-null  object
#  11  menu_item     43499 non-null  object
#  12  type          43499 non-null  object
#  13  city          43499 non-null  object
# dtypes: int64(1), object(13)
# memory usage: 5.0+ MB

# %%
zomato3['cost']
# Out:
# 0          800
# 1          800
# 2          800
# 3          300
# 4          600
#          ...
# 51709      800
# 51711      800
# 51712    1,500
# 51715    2,500
# 51716    1,500
# Name: cost, Length: 43499, dtype: object

# %%
zomato3['cost']=zomato3['cost'].astype(str)

# %%
zomato3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43499 entries, 0 to 51716
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   address       43499 non-null  object
#  1   name          43499 non-null  object
#  2   online_order  43499 non-null  object
#  3   book_table    43499 non-null  object
#  4   rate          43499 non-null  object
#  5   votes         43499 non-null  int64
#  6   location      43499 non-null  object
#  7   rest_type     43499 non-null  object
#  8   cuisines      43499 non-null  object
#  9   cost          43499 non-null  object
#  10  reviews_list  43499 non-null  object
#  11  menu_item     43499 non-null  object
#  12  type          43499 non-null  object
#  13  city          43499 non-null  object
# dtypes: int64(1), object(13)
# memory usage: 5.0+ MB

# %%
zomato3['cost']=zomato3['cost'].apply(lambda x:x.replace(',','.'))

# %%
zomato3['cost']
# Out:
# 0          800
# 1          800
# 2          800
# 3          300
# 4          600
#          ...
# 51709      800
# 51711      800
# 51712    1.500
# 51715    2.500
# 51716    1.500
# Name: cost, Length: 43499, dtype: object

# %%
zomato3['cost']=zomato3['cost'].astype('float')

# %%
zomato3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43499 entries, 0 to 51716
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   address       43499 non-null  object
#  1   name          43499 non-null  object
#  2   online_order  43499 non-null  object
#  3   book_table    43499 non-null  object
#  4   rate          43499 non-null  object
#  5   votes         43499 non-null  int64
#  6   location      43499 non-null  object
#  7   rest_type     43499 non-null  object
#  8   cuisines      43499 non-null  object
#  9   cost          43499 non-null  float64
#  10  reviews_list  43499 non-null  object
#  11  menu_item     43499 non-null  object
#  12  type          43499 non-null  object
#  13  city          43499 non-null  object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 5.0+ MB

# %%
zomato3['rate']
# Out:
# 0         4.1/5
# 1         4.1/5
# 2         3.8/5
# 3         3.7/5
# 4         3.8/5
#           ...
# 51709    3.7 /5
# 51711    2.5 /5
# 51712    3.6 /5
# 51715    4.3 /5
# 51716    3.4 /5
# Name: rate, Length: 43499, dtype: object

# %%
zomato3['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
zomato3.shape
# Out:
# (43499, 14)

# %%
zomato4=zomato3.loc[zomato3['rate']!='NEW']

# %%
zomato4.shape
# Out:
# (41302, 14)

# %%
43499-41302
# Out:
# 2197

# %%
zomato5=zomato4.loc[zomato4['rate']!='-']

# %%
zomato5.shape
# Out:
# (41237, 14)

# %%
zomato5['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', '2.9/5', '3.5/5', '2.6/5', '3.8 /5', '3.4/5', '4.5/5',
#        '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5', '3.4 /5',
#        '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5', '4.1 /5',
#        '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5', '3.5 /5',
#        '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5', '4.3 /5',
#        '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5', '4.9 /5',
#        '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5', '2.1 /5',
#        '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
remove_slash=lambda x:x.replace('/5','') if type(x)==np.str else x

# %%
'     hello    '.strip()
# Out:
# 'hello'

# %%
zomato5['rate']=zomato5['rate'].apply(remove_slash).str.strip().astype('float')
# Out:
# C:\Users\arana\AppData\Local\Temp\ipykernel_6468\241488642.py:1: FutureWarning: In the future `np.str` will be defined as the corresponding NumPy scalar.
#   remove_slash=lambda x:x.replace('/5','') if type(x)==np.str else x
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 zomato5['rate']=zomato5['rate'].apply(remove_slash).str.strip().astype('float')
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# ...

# %%
zomato5.info()

# %%
zomato5['rate']
# Out:
# 0         4.1/5
# 1         4.1/5
# 2         3.8/5
# 3         3.7/5
# 4         3.8/5
#           ...
# 51709    3.7 /5
# 51711    2.5 /5
# 51712    3.6 /5
# 51715    4.3 /5
# 51716    3.4 /5
# Name: rate, Length: 41237, dtype: object

# %%
zomato5
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
zomato5['name']=zomato5['name'].apply(lambda x:x.title())
# Out:
# C:\Users\arana\AppData\Local\Temp\ipykernel_6468\2092995913.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zomato5['name']=zomato5['name'].apply(lambda x:x.title())

# %%
zomato5.head()
# Out:
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes      location            rest_type  \
# 0          Yes        Yes  4.1/5    775  Banashankari        Casual Dining
# 1          Yes         No  4.1/5    787  Banashankari        Casual Dining
# 2          Yes         No  3.8/5    918  Banashankari  Cafe, Casual Dining
# 3           No         No  3.7/5     88  Banashankari          Quick Bites
# 4           No         No  3.8/5    166  Basavanagudi        Casual Dining
#
#                          cuisines   cost  \
# ...

# %%
zomato5['online_order'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
zomato5['online_order'].replace(('Yes','No'),(True,False),inplace=True)
# Out:
# C:\Users\arana\AppData\Local\Temp\ipykernel_6468\994481535.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zomato5['online_order'].replace(('Yes','No'),(True,False),inplace=True)

# %%
zomato5.head()
# Out:
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#    online_order book_table   rate  votes      location            rest_type  \
# 0          True        Yes  4.1/5    775  Banashankari        Casual Dining
# 1          True         No  4.1/5    787  Banashankari        Casual Dining
# 2          True         No  3.8/5    918  Banashankari  Cafe, Casual Dining
# 3         False         No  3.7/5     88  Banashankari          Quick Bites
# 4         False         No  3.8/5    166  Basavanagudi        Casual Dining
#
#                          cuisines   cost  \
# ...

# %%
zomato5['book_table'].replace(('Yes','No'),(True,False),inplace=True)
# Out:
# C:\Users\arana\AppData\Local\Temp\ipykernel_6468\3775350019.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zomato5['book_table'].replace(('Yes','No'),(True,False),inplace=True)

# %%
zomato5.head()
# Out:
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#    online_order  book_table   rate  votes      location            rest_type  \
# 0          True        True  4.1/5    775  Banashankari        Casual Dining
# 1          True       False  4.1/5    787  Banashankari        Casual Dining
# 2          True       False  3.8/5    918  Banashankari  Cafe, Casual Dining
# 3         False       False  3.7/5     88  Banashankari          Quick Bites
# 4         False       False  3.8/5    166  Basavanagudi        Casual Dining
#
#                          cuisines   cost  \
# ...

# %%
zomato5['cost'].unique()
# Out:
# array([800.  , 300.  , 600.  , 700.  , 550.  , 500.  , 450.  , 650.  ,
#        400.  , 900.  , 200.  , 750.  , 150.  , 850.  , 100.  ,   1.2 ,
#        350.  , 250.  , 950.  ,   1.  ,   1.5 ,   1.3 , 199.  ,   1.1 ,
#          1.6 , 230.  , 130.  ,   1.7 ,   1.35,   2.2 ,   1.4 ,   2.  ,
#          1.8 ,   1.9 , 180.  , 330.  ,   2.5 ,   2.1 ,   3.  ,   2.8 ,
#          3.4 ,  50.  ,  40.  ,   1.25,   3.5 ,   4.  ,   2.4 ,   2.6 ,
#          1.45,  70.  ,   3.2 , 240.  ,   6.  ,   1.05,   2.3 ,   4.1 ,
#        120.  ,   5.  ,   3.7 ,   1.65,   2.7 ,   4.5 ,  80.  ])

# %%
zomato5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41237 entries, 0 to 51716
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   address       41237 non-null  object
#  1   name          41237 non-null  object
#  2   online_order  41237 non-null  bool
#  3   book_table    41237 non-null  bool
#  4   rate          41237 non-null  object
#  5   votes         41237 non-null  int64
#  6   location      41237 non-null  object
#  7   rest_type     41237 non-null  object
#  8   cuisines      41237 non-null  object
#  9   cost          41237 non-null  float64
#  10  reviews_list  41237 non-null  object
#  11  menu_item     41237 non-null  object
#  12  type          41237 non-null  object
#  13  city          41237 non-null  object
# dtypes: bool(2), float64(1), int64(1), object(10)
# memory usage: 4.2+ MB

# %%
zomato5.head()
# Out:
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#    online_order  book_table   rate  votes      location            rest_type  \
# 0          True        True  4.1/5    775  Banashankari        Casual Dining
# 1          True       False  4.1/5    787  Banashankari        Casual Dining
# 2          True       False  3.8/5    918  Banashankari  Cafe, Casual Dining
# 3         False       False  3.7/5     88  Banashankari          Quick Bites
# 4         False       False  3.8/5    166  Basavanagudi        Casual Dining
#
#                          cuisines   cost  \
# ...

# %%
zomato5['name'].factorize()
# Out:
# (array([   0,    1,    2, ..., 6532, 6568, 6569], dtype=int64),
#  Index(['Jalsa', 'Spice Elephant', 'San Churro Cafe', 'Addhuri Udupi Bhojana',
#         'Grand Village', 'Timepass Dinner',
#         'Rosewood International Hotel - Bar & Restaurant', 'Onesta',
#         'Penthouse Cafe', 'Smacznego',
#         ...
#         'Food Dig', 'Ishwaryam', 'Hungry Wok', 'Mad Kitchen', 'Polly'S Kitchen',
#         'Calcutta North Indian Meals',
#         'Chime - Sheraton Grand Bengaluru Whitefield Hotel &...',
#         'The Nest - The Den Bengaluru', 'Nawabs Empire', 'Seeya Restaurant'],
#        dtype='object', length=6572))

# %%
type(zomato5['name'].factorize())
# Out:
# tuple

# %%
zomato5['name'].factorize()[0]
# Out:
# array([   0,    1,    2, ..., 6532, 6568, 6569], dtype=int64)

# %%
zomato5
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name  online_order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# ...

# %%
zomato5_copy=zomato5.copy()

# %%
zomato5_copy
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name  online_order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# ...

# %%
def convert_nos(z):
    for column in z.columns[~z.columns.isin(['rate','cost','votes'])]:
        z[column]=z[column].factorize()[0]
    return z

# %%
zomato5
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name  online_order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# ...

# %%
zomato5_encoded=convert_nos(zomato5_copy)

# %%
pwd
# Out:
# 'C:\\Users\\arana\\Desktop\\Ml Add on'

# %%
zomato5_encoded
# Out:
#        address  name  online_order  book_table    rate  votes  location  \
# 0            0     0             0           0   4.1/5    775         0
# 1            1     1             0           1   4.1/5    787         0
# 2            2     2             0           1   3.8/5    918         0
# 3            3     3             1           1   3.7/5     88         0
# 4            4     4             1           1   3.8/5    166         1
# ...        ...   ...           ...         ...     ...    ...       ...
# 51709     3137  2699             1           1  3.7 /5     34        25
# 51711     8791  1716             1           1  2.5 /5     81        25
# 51712     8725  6532             1           1  3.6 /5     27        25
# 51715     8786  6568             1           0  4.3 /5    236        56
# 51716     3444  6569             1           1  3.4 /5     13        56
#
#        rest_type  cuisines   cost  reviews_list  menu_item  type  city
# ...

# %%
zomato5_encoded.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 zomato5_encoded.corr()
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
corr=zomato5_encoded.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 corr=zomato5_encoded.corr()
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
plt.figure(figsize=(12,10))
sns.heatmap(corr,annot=True,cmap='Set2')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[76], line 2
#       1 plt.figure(figsize=(12,10))
# ----> 2 sns.heatmap(corr,annot=True,cmap='Set2')
#
# NameError: name 'corr' is not defined

# %%
zomato5_copy
# Out:
#        address  name  online_order  book_table    rate  votes  location  \
# 0            0     0             0           0   4.1/5    775         0
# 1            1     1             0           1   4.1/5    787         0
# 2            2     2             0           1   3.8/5    918         0
# 3            3     3             1           1   3.7/5     88         0
# 4            4     4             1           1   3.8/5    166         1
# ...        ...   ...           ...         ...     ...    ...       ...
# 51709     3137  2699             1           1  3.7 /5     34        25
# 51711     8791  1716             1           1  2.5 /5     81        25
# 51712     8725  6532             1           1  3.6 /5     27        25
# 51715     8786  6568             1           0  4.3 /5    236        56
# 51716     3444  6569             1           1  3.4 /5     13        56
#
#        rest_type  cuisines   cost  reviews_list  menu_item  type  city
# ...

# %%
zomato5_copy
# Out:
#        address  name  online_order  book_table    rate  votes  location  \
# 0            0     0             0           0   4.1/5    775         0
# 1            1     1             0           1   4.1/5    787         0
# 2            2     2             0           1   3.8/5    918         0
# 3            3     3             1           1   3.7/5     88         0
# 4            4     4             1           1   3.8/5    166         1
# ...        ...   ...           ...         ...     ...    ...       ...
# 51709     3137  2699             1           1  3.7 /5     34        25
# 51711     8791  1716             1           1  2.5 /5     81        25
# 51712     8725  6532             1           1  3.6 /5     27        25
# 51715     8786  6568             1           0  4.3 /5    236        56
# 51716     3444  6569             1           1  3.4 /5     13        56
#
#        rest_type  cuisines   cost  reviews_list  menu_item  type  city
# ...

# %%
zomato5
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name  online_order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# ...

# %%
zomato5.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'cuisines', 'cost', 'reviews_list',
#        'menu_item', 'type', 'city'],
#       dtype='object')

# %%
sns.countplot(zomato5['book_table'])
fig=plt.gcf()
fig.set_size_inches(8,5)
plt.title("Restaurants Allowing Online table Booking")
plt.show()
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
zomato5.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'cuisines', 'cost', 'reviews_list',
#        'menu_item', 'type', 'city'],
#       dtype='object')

# %%
sns.countplot(zomato5['online_order'])
fig=plt.gcf()
fig.set_size_inches(8,5)
plt.title("Restaurants Allowing Online Order Booking")
plt.show()

# %%
pd.crosstab(zomato5['rate'],zomato5['online_order'])

# %%
pd.crosstab(zomato5['rate'],zomato5['book_table'])

# %%
z=pd.crosstab(zomato5['rate'],zomato5['book_table'])

# %%
type(z)

# %%
z.sum()

# %%
plt.rcParams['figure.figsize']=(12,8)
z.div(z.sum(1).astype(float),axis=0).plot(kind="bar",stacked=True,color=['green','red'])

# %%
zomato5['city'].unique()

# %%
zomato5['city'].nunique()

# %%
sns.countplot(zomato5['city']).set_xticklabels(sns.countplot(zomato5['city']).get_xticklabels(),
            rotation=90,ha="right")
plt.show()

# %%
sns.countplot(zomato5['type']).set_xticklabels(sns.countplot(zomato5['type']).get_xticklabels(),
            rotation=90,ha="right")
plt.show()
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Admin\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(zomato5['cost']).set_xticklabels(sns.countplot(zomato5['cost']).get_xticklabels(),
            rotation=90,ha="right")
plt.show()
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Admin\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
zomato5['name'].value_counts()[:10]
# Out:
# Cafe Coffee Day      86
# Onesta               85
# Empire Restaurant    69
# Kanti Sweets         68
# Just Bake            68
# Five Star Chicken    68
# Baskin Robbins       62
# Kfc                  60
# Petoo                60
# Pizza Hut            60
# Name: name, dtype: int64

# %%
z1=zomato5['name'].value_counts()[:20]

# %%
type(z1)  #time to commet on the losser who cheated on the datype of the
# Out:
# pandas.core.series.Series

# %%
z1.index
# Out:
# Index(['Cafe Coffee Day', 'Onesta', 'Empire Restaurant', 'Kanti Sweets',
#        'Just Bake', 'Five Star Chicken', 'Baskin Robbins', 'Kfc', 'Petoo',
#        'Pizza Hut'],
#       dtype='object')

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=z1,y=z1.index,palette="rainbow")
# Out:
# <AxesSubplot:xlabel='name'>

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=z1,y=z1.index,palette="Set1")
# Out:
# <AxesSubplot:xlabel='name'>

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=z1,y=z1.index,palette="Set2")
# Out:
# <AxesSubplot:xlabel='name'>

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=z1,y=z1.index,palette="Set3")
# Out:
# <AxesSubplot:xlabel='name'>

# %%
## Diabetes Use Case

# %%
pwd
# Out:
# 'C:\\Users\\Admin'

# %%
d1=pd.read_csv("diabetes.csv")

# %%
d1.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
d1.shape
# Out:
# (768, 9)

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
d1.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
type(d1.describe())
# Out:
# pandas.core.frame.DataFrame

# %%
d1.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
d1_copy=d1.copy(deep=True)

# %%
d1[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin','BMI']]=d1[['Glucose', 'BloodPressure', 
    'SkinThickness', 'Insulin','BMI']].replace(0,np.nan)

# %%
d1.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
d1.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0      NaN  33.6
# 1            1     85.0           66.0           29.0      NaN  26.6
# 2            8    183.0           64.0            NaN      NaN  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
d1.hist(figsize=(15,10))
# Out:
# array([[<AxesSubplot:title={'center':'Pregnancies'}>,
#         <AxesSubplot:title={'center':'Glucose'}>,
#         <AxesSubplot:title={'center':'BloodPressure'}>],
#        [<AxesSubplot:title={'center':'SkinThickness'}>,
#         <AxesSubplot:title={'center':'Insulin'}>,
#         <AxesSubplot:title={'center':'BMI'}>],
#        [<AxesSubplot:title={'center':'DiabetesPedigreeFunction'}>,
#         <AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Outcome'}>]], dtype=object)

# %%
d1.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
sns.boxplot(data=d1)
# Out:
# <AxesSubplot:>

# %%
q=d1['Pregnancies'].quantile(0.98)

# %%
q
# Out:
# 12.0

# %%
d1['Pregnancies']<q
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 763    True
# 764    True
# 765    True
# 766    True
# 767    True
# Name: Pregnancies, Length: 768, dtype: bool

# %%
d1[d1['Pregnancies']<q]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0      NaN  33.6
# 1              1     85.0           66.0           29.0      NaN  26.6
# 2              8    183.0           64.0            NaN      NaN  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0           48.0    180.0  32.9
# 764            2    122.0           70.0           27.0      NaN  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0           60.0            NaN      NaN  30.1
# 767            1     93.0           70.0           31.0      NaN  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
d1_cleaned=d1[d1['Pregnancies']<q]

# %%
d1_cleaned.shape
# Out:
# (745, 9)

# %%
q=d1['BMI'].quantile(0.99)
d1_cleaned=d1_cleaned[d1_cleaned['BMI']<q]

# %%
d1_cleaned.shape
# Out:
# (726, 9)

# %%
q=d1['SkinThickness'].quantile(0.99)
d1_cleaned=d1_cleaned[d1_cleaned['SkinThickness']<q]

# %%
d1_cleaned.shape
# Out:
# (513, 9)

# %%
q=d1['Insulin'].quantile(0.96)
d1_cleaned=d1_cleaned[d1_cleaned['Insulin']<q]

# %%
d1_cleaned.shape
# Out:
# (360, 9)

# %%
d1.hist(figsize=(15,10))
# Out:
# array([[<AxesSubplot:title={'center':'Pregnancies'}>,
#         <AxesSubplot:title={'center':'Glucose'}>,
#         <AxesSubplot:title={'center':'BloodPressure'}>],
#        [<AxesSubplot:title={'center':'SkinThickness'}>,
#         <AxesSubplot:title={'center':'Insulin'}>,
#         <AxesSubplot:title={'center':'BMI'}>],
#        [<AxesSubplot:title={'center':'DiabetesPedigreeFunction'}>,
#         <AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Outcome'}>]], dtype=object)

# %%
d1_cleaned['BMI'].isnull().sum()
# Out:
# 0

# %%
d1_cleaned['BMI'].fillna(d1['BMI'].mean(),inplace=True)

# %%
d1_cleaned
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# 6              3     78.0           50.0           32.0     88.0  31.0
# 14             5    166.0           72.0           19.0    175.0  25.8
# 16             0    118.0           84.0           47.0    230.0  45.8
# ..           ...      ...            ...            ...      ...   ...
# 751            1    121.0           78.0           39.0     74.0  39.0
# 755            1    128.0           88.0           39.0    110.0  36.5
# 760            2     88.0           58.0           26.0     16.0  28.4
# 763           10    101.0           76.0           48.0    180.0  32.9
# 765            5    121.0           72.0           23.0    112.0  26.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# 3                       0.167   21        0
# ...

# %%
d1_cleaned.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     1
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
d1_cleaned['Glucose'].fillna(d1['Glucose'].mean(),inplace=True)

# %%
d1_cleaned.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
d1_cleaned.hist(figsize=(15,15))
# Out:
# array([[<AxesSubplot:title={'center':'Pregnancies'}>,
#         <AxesSubplot:title={'center':'Glucose'}>,
#         <AxesSubplot:title={'center':'BloodPressure'}>],
#        [<AxesSubplot:title={'center':'SkinThickness'}>,
#         <AxesSubplot:title={'center':'Insulin'}>,
#         <AxesSubplot:title={'center':'BMI'}>],
#        [<AxesSubplot:title={'center':'DiabetesPedigreeFunction'}>,
#         <AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Outcome'}>]], dtype=object)

# %%
d1_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 360 entries, 3 to 765
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               360 non-null    int64
#  1   Glucose                   360 non-null    float64
#  2   BloodPressure             360 non-null    float64
#  3   SkinThickness             360 non-null    float64
#  4   Insulin                   360 non-null    float64
#  5   BMI                       360 non-null    float64
#  6   DiabetesPedigreeFunction  360 non-null    float64
#  7   Age                       360 non-null    int64
#  8   Outcome                   360 non-null    int64
# dtypes: float64(6), int64(3)
# memory usage: 28.1 KB

# %%
import missingno as msno

# %%
msno.bar(d1)
# Out:
# <AxesSubplot:>

# %%
msno.bar(d1_cleaned)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(d1_cleaned,hue='Outcome').add_legend()

# %%
d1_cleaned.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.244042       0.224620       0.141607
# Glucose                      0.244042  1.000000       0.209019       0.150354
# BloodPressure                0.224620  0.209019       1.000000       0.215102
# SkinThickness                0.141607  0.150354       0.215102       1.000000
# Insulin                      0.141089  0.597167       0.119931       0.197752
# BMI                          0.018119  0.187875       0.294960       0.649708
# DiabetesPedigreeFunction     0.003685  0.097354      -0.034340       0.105724
# Age                          0.679153  0.360094       0.333800       0.205846
# Outcome                      0.256703  0.516423       0.225724       0.255576
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies               0.141089  0.018119                  0.003685
# ...

# %%
sns.heatmap(d1_cleaned.corr(),annot=True,cmap='Set1')
# Out:
# <AxesSubplot:>
